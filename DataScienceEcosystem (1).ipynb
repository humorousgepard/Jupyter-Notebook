# %% [markdown]
# ## Data Science Tools and Ecosystem

# %% [markdown]
# This note book is about Data Science Tools and Ecosystem summary

# %% [markdown]
# **Objectives:**
#
# - Popular languages for Data Science
# - Popular libraries for Data Science
# - Popular Data science Tools
# - Simple Arithmetic evaluations

# %% [markdown]
# Here are some languages that are commonly used in Data Science:
# 1. Python
# 2. R
# 3. SQL (Structured Query Language)

# %% [markdown]
# There are many libraries used by Data Scientists such as:
# 1. Sickit-Learn
# 2. Pandas
# 3. Nympy

# %% [markdown]
# Data Science Tools:
#
#     1. VS Code
#     2. Gitlab
#     3. Tensorflow

# %% [markdown]
# Here is some evalution of arithmetetic expressions in Python:

# %%
#This is a basic arithmetic expression multiply then add integers
(3*4)+5
# Out:
# 17

# %%
#this will convert the minutes to hours
minutes = 200
hours = minutes/60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Bence Fartek
